# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import symbols, diff
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sympy import lambdify

# %%
j , k = symbols('j k', real=True) #seteo las variables
f = k**2 - 2*j*k + 2j**2 + 18*j - 20*k + 201 + 4 
f
# Out:
# -2*j*k + 18*j + k**2 - 20*k + 201.0

# %% [markdown]
# REVISAR: no se por que el 201 me lo toma como 197

# %%
#derivadas parciales
df_dj = diff(f, j)
df_dk = diff(f, k)

# %%
# Malla de puntos para graficar
X = np.linspace(-4, 4, 100)
Y = np.linspace(-4, 4, 100)
X, Y = np.meshgrid(X, Y)
Z = lambdify((j, k), f, 'numpy')(X, Y)

# Graficar
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.view_init(elev=20, azim=150)  # Puedes ajustar los valores de elev y azim para cambiar la vista
ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.9)

ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ### Tecnica de descenso de gradiente

# %%
alpha = 0.1
iterations = 100
px = 0
py = 0

# %%
for i in range (iterations):

    #evaluo las derivadas parciales en el punto actual --> GRADIENTE
    grad_x = df_dj.evalf(subs={j:px, k:py})
    grad_y = df_dk.evalf(subs={j:px, k:py})

    #actualizo las coordenadas en la direccion OPUESTA al gradiente (por eso se resta)
    px = px - alpha * grad_x
    py = py - alpha * grad_y

    #evaluar la funcion en el nuevo punto
    f_val = f.evalf(subs={j:px, k:py})

    #iteracion 
    print(f' Iteracion {i+1}, la funcion f(x,y) = {f_val}')


print( " ")
print (f'Resultado final: j{px}, k{py}, f(x,y) = {f_val}')
# Out:
#  Iteracion 1, la funcion f(x,y) = -196885090626.829
#  Iteracion 2, la funcion f(x,y) = -248565898317.451
#  Iteracion 3, la funcion f(x,y) = -313812516774.483
#  Iteracion 4, la funcion f(x,y) = -396185865998.477
#  Iteracion 5, la funcion f(x,y) = -500181579842.963
#  Iteracion 6, la funcion f(x,y) = -631475361143.701
#  Iteracion 7, la funcion f(x,y) = -797232740664.395
#  Iteracion 8, la funcion f(x,y) = -1006500145360.68
#  Iteracion 9, la funcion f(x,y) = -1270698619027.15
#  Iteracion 10, la funcion f(x,y) = -1604247140780.88
#  Iteracion 11, la funcion f(x,y) = -2025349559807.57
#  Iteracion 12, la funcion f(x,y) = -2556988094368.50
#  Iteracion 13, la funcion f(x,y) = -3228177616583.49
#  Iteracion 14, la funcion f(x,y) = -4075549177230.89
#  Iteracion 15, la funcion f(x,y) = -5145349193513.03
#  Iteracion 16, la funcion f(x,y) = -6495963408088.37
#  Iteracion 17, la funcion f(x,y) = -8201103367753.40
#  Iteracion 18, la funcion f(x,y) = -10353829328038.5
# ...

# %% [markdown]
# REVISAR: verificar que este procedimiento este bien
