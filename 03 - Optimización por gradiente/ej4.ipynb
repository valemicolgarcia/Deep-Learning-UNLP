# %% [markdown]
# # Ejercicio 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importe de librerias

# %%
from ClassNeuronaLineal import NeuronaLineal
import pandas as pd
import numpy as np

# %%
ColabNotebook = 'google.colab' in str(get_ipython())

if ColabNotebook: # maquina virtual colab
    # monta G-drive en entorno COLAB
    from google.colab import drive
    drive.mount('/content/drive/')

    # carpeta donde se encuentran archivos .py auxiliares
    FUENTES_DIR  = '/content/drive/MyDrive/Colab Notebooks/FUENTES/'
    DATOS_DIR    = '/content/drive/MyDrive/Colab Notebooks/DATOS/'      # carpeta donde se encuentran los datasets
    MODELOS_DIR  = '/content/drive/MyDrive/Colab Notebooks/MODELOS/'    # carpeta donde se encuentran los modelos
    ARCHIVOS_DIR = '/content/drive/MyDrive/Colab Notebooks/ARCHIVOS/'   # carpeta recuperar o copiar archivos
else: # maquina local ipython
    # configuración para notebook con instalación LOCAL
    FUENTES_DIR  = '../Fuentes'     # carpeta donde se encuentran archivos .py auxiliares
    DATOS_DIR    = '../Datos/'      # carpeta donde se encuentran los datasets
    MODELOS_DIR  = '../Modelos/'    # carpeta donde se encuentran los modelos
    ARCHIVOs_DIR = '../Archivos/'   # carpeta recuperar o copiar archivos

# agrega ruta de busqueda donde tenemos archivos .py
import sys
sys.path.append(FUENTES_DIR)

# %% [markdown]
# # Lectura del ds

# %%
import pandas as pd      # para trabajar con archivos de datos csv, excel, etc: https://pandas.pydata.org/docs/getting_started/tutorials.html
import chardet           # para detectar la codificación de texto en archivos


nombre_archivo = DATOS_DIR + 'CCPP.csv' # archivo de hojas

#-- detectando la codificación de caracteres usada ----
with open(nombre_archivo, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

# recupera el archivo en un objeto dataframe de pandas utilizando la codificación detectada
df = pd.read_csv(nombre_archivo, encoding=result['encoding'])

# visualiza el dataframe

display(df)
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# # Prediccion con neurona lineal

# %% [markdown]
# - 5 combinadores lineales
# - predecir PE a partir del atributo AT
# - BUSCAR DOS COMBINADORES LINEALES CON MENOR ERROR

# %% [markdown]
# Selecciono x e y y los transformo los dataframe de pandas a numpy array para poder mandarselos a la neurona lineal

# %%
X = np.array(df['AT'])
Y = np.array(df['PE'])

X = X.reshape(-1,1)
print(X)
print(Y)
# Out:
# [[14.96]
#  [25.18]
#  [ 5.11]
#  ...
#  [31.32]
#  [24.48]
#  [21.6 ]]
# [463.26 444.37 488.56 ... 429.57 435.74 453.28]

# %%
modelo = NeuronaLineal(alpha=0.0001, n_iter=50, cotaE=0.001, draw=1, title=['x: AT', 'y: PE'])

# %%
modelo.fit(X,Y)

# %%
# imprime pesos
print('Pesos de la Neurona:')
print('  w =', modelo.w_)
print('  b =', modelo.b_)
# Out:
# Pesos de la Neurona:
#   w = [-2.15651542]
#   b = 495.78599278509415

# %% [markdown]
# # Pruebas

# %%
AT = df['AT'].values
PE = df['PE'].values

# %%
combinadores = {
    'a': (-2.00, 500),
    'b': (-2.21, 498),
    'c': (-2.30, 497),
    'd': (-2.22, 496.5),
    'e': (-2.16, 496.91)
}

# %%
def calcular_ecm(W, b, AT, PE):
    predicciones = W * AT + b  # Fórmula para predecir PE
    ecm = np.mean((PE - predicciones) ** 2)  # Calcular el error cuadrático medio
    return ecm

# %% [markdown]
# ### Combinador lineal A

# %%
W, b = combinadores['a']
ecm = calcular_ecm(W,b,AT,PE)
ecm
# Out:
# 71.1625547554348

# %% [markdown]
# ### Combinador lineal B

# %%
W, b = combinadores['b']
ecm = calcular_ecm(W,b,AT,PE)
ecm
# Out:
# 29.55712944886288

# %% [markdown]
# ### Combinador lineal C

# %%
W, b = combinadores['c']
ecm = calcular_ecm(W,b,AT,PE)
ecm
# Out:
# 36.91941198244145

# %% [markdown]
# ### Combinador lineal D

# %%
W, b = combinadores['d']
ecm = calcular_ecm(W,b,AT,PE)
ecm
# Out:
# 31.785616074548507

# %% [markdown]
# ### Combinador lineal E

# %%
W, b = combinadores['e']
ecm = calcular_ecm(W,b,AT,PE)
ecm
# Out:
# 29.44848719225753

# %% [markdown]
# ### RESPUESTA

# %% [markdown]
# Los dos combinadores lineales que tienen menor error son el b y el e
