# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(1337)

#-- Cargar sólo las imágenes sin las etiquetas ---
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

##-- Visualizando las imágenes ruidosas --
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
##--- definición del modelo --
input_img = layers.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# En este punto la representación es de (7, 7, 32)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Entrenando elautoencoder
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/100
# 469/469 [==============================] - 42s 87ms/step - loss: 0.1753 - val_loss: 0.1202
# Epoch 2/100
# 469/469 [==============================] - 41s 88ms/step - loss: 0.1156 - val_loss: 0.1104
# Epoch 3/100
# 469/469 [==============================] - 40s 86ms/step - loss: 0.1093 - val_loss: 0.1058
# Epoch 4/100
# 469/469 [==============================] - 39s 83ms/step - loss: 0.1058 - val_loss: 0.1036
# Epoch 5/100
# 469/469 [==============================] - 39s 84ms/step - loss: 0.1038 - val_loss: 0.1021
# Epoch 6/100
# 469/469 [==============================] - 40s 84ms/step - loss: 0.1022 - val_loss: 0.1006
# Epoch 7/100
# 469/469 [==============================] - 46s 98ms/step - loss: 0.1011 - val_loss: 0.0996
# Epoch 8/100
# 469/469 [==============================] - 40s 85ms/step - loss: 0.1003 - val_loss: 0.0991
# Epoch 9/100
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0996 - val_loss: 0.0984
# Epoch 10/100
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0989 - val_loss: 0.0978
# Epoch 11/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0984 - val_loss: 0.0975
# Epoch 12/100
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0979 - val_loss: 0.0975
# Epoch 13/100
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0975 - val_loss: 0.0966
# Epoch 14/100
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0972 - val_loss: 0.0964
# Epoch 15/100
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0969 - val_loss: 0.0960
# Epoch 16/100
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0966 - val_loss: 0.0960
# Epoch 17/100
# 469/469 [==============================] - 41s 86ms/step - loss: 0.0964 - val_loss: 0.0961
# Epoch 18/100
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0962 - val_loss: 0.0956
# Epoch 19/100
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0960 - val_loss: 0.0953
# Epoch 20/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0959 - val_loss: 0.0955
# Epoch 21/100
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0957 - val_loss: 0.0951
# Epoch 22/100
# 469/469 [==============================] - 42s 89ms/step - loss: 0.0956 - val_loss: 0.0951
# Epoch 23/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0954 - val_loss: 0.0948
# Epoch 24/100
# 469/469 [==============================] - 39s 83ms/step - loss: 0.0953 - val_loss: 0.0952
# Epoch 25/100
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0952 - val_loss: 0.0947
# Epoch 26/100
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0951 - val_loss: 0.0947
# Epoch 27/100
# 469/469 [==============================] - 39s 83ms/step - loss: 0.0950 - val_loss: 0.0946
# Epoch 28/100
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0949 - val_loss: 0.0949
# Epoch 29/100
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0948 - val_loss: 0.0947
# Epoch 30/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0948 - val_loss: 0.0943
# Epoch 31/100
# 469/469 [==============================] - 45s 96ms/step - loss: 0.0947 - val_loss: 0.0944
# Epoch 32/100
# 469/469 [==============================] - 42s 89ms/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 33/100
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0945 - val_loss: 0.0942
# Epoch 34/100
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0945 - val_loss: 0.0943
# Epoch 35/100
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0945 - val_loss: 0.0943
# Epoch 36/100
# 469/469 [==============================] - 43s 92ms/step - loss: 0.0944 - val_loss: 0.0951
# Epoch 37/100
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 38/100
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 39/100
# 469/469 [==============================] - 40s 84ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 40/100
# 469/469 [==============================] - 63s 135ms/step - loss: 0.0942 - val_loss: 0.0941
# Epoch 41/100
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0941 - val_loss: 0.0941
# Epoch 42/100
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 43/100
# 469/469 [==============================] - 73s 156ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 44/100
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 45/100
# 469/469 [==============================] - 74s 157ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 46/100
# 469/469 [==============================] - 78s 165ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 47/100
# 469/469 [==============================] - 81s 172ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 48/100
# 469/469 [==============================] - 81s 173ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 49/100
# 469/469 [==============================] - 84s 180ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 50/100
# 469/469 [==============================] - 79s 169ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 51/100
# 469/469 [==============================] - 72s 154ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 52/100
# 469/469 [==============================] - 77s 163ms/step - loss: 0.0938 - val_loss: 0.0940
# Epoch 53/100
# 469/469 [==============================] - 76s 163ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 54/100
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 55/100
# 469/469 [==============================] - 74s 158ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 56/100
# 469/469 [==============================] - 76s 163ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 57/100
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 58/100
# 469/469 [==============================] - 67s 142ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 59/100
# 469/469 [==============================] - 53s 113ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 60/100
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 61/100
# 469/469 [==============================] - 48s 102ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 62/100
# 469/469 [==============================] - 48s 102ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 63/100
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 64/100
# 469/469 [==============================] - 53s 113ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 65/100
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 66/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 67/100
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 68/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 69/100
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 70/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0935 - val_loss: 0.0938
# Epoch 71/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 72/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 73/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 74/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 75/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0934 - val_loss: 0.0935
# Epoch 76/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 77/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 78/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 79/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 80/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 81/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 82/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 83/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0933 - val_loss: 0.0936
# Epoch 84/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 85/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 86/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 87/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 88/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 89/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 90/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 91/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 92/100
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 93/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 94/100
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 95/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 96/100
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 36s 78ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 98/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 99/100
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 100/100
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0931 - val_loss: 0.0931

# %%
# Predicción del Autoencoder para las imágenes de testeo
decoded_imgs = autoencoder.predict(x_test_noisy)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruccion
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
